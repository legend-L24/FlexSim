# %% [markdown]
# ## I want to analyse a force deviation for MD trajectories

# %%
from ase.io import read, write

atoms = read('/capstor/scratch/cscs/lyutao/activelearning/ZnMOF_iter1_better/mof5_data/2/devi_0508/SAHYIK_2w_500K_1_devi.xyz', index=':')

# %%
for atom in atoms[:]:
    forces_model1
